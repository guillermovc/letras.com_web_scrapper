# %% [markdown]
# # Getting music lyrics usign Web Scrapping

# %% [markdown]
# This short notebook is designed to automatically obtaining song lyrics from the page [letras.com](www.letras.com) using web scrapping, requiring only the main link of an artist on the page.

# %% [markdown]
# ## Needed libraries

# %%
# The only library you'll need to install is Beautiful Soup 4 (use: "pip install beautifulsoup4").
from bs4 import BeautifulSoup as bs

# The last three libraries are from the python standard library.
import requests     # To make web requests
import time         # To measure time
import json         # To handle json files
import re           # To use regular expressions

# %% [markdown]
# ## Put here your artist main link from letras.com and its name

# %%
url_base = 'https://www.letras.com/imagine-dragons/'

# %% [markdown]
# ## Concatenating necessary link to acces to the artist song list

# %%
url = url_base + 'mais_acessadas.html'
page = requests.get(url)
assert str(page) == '<Response [200]>', 'Bad response from URL'

# %% [markdown]
# ## Scrapping page content

# %%
# Parsing web content with BeautifulSoup
soup = bs(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html dir="ltr" lang="es">
#  <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
#   <title>
#    Imagine Dragons - LETRAS.COM (167 canciones)
#   </title>
#   <meta content='Ver las letras de Imagine Dragons y escuchar "Believer",  "Demons",  "Bad Liar",  "Bones",  "Not Today",  "Natural",  "Thunder",  "Radioactive" y más canciones!' name="description"/>
#   <meta content="  letras de músicas, Imagine Dragons letras, músicas, letra de música, letra, letras de música, legendas, vídeos  " name="keywords"/>
#   <link href="https://www.letras.com/imagine-dragons/" rel="canonical"/>
#   <meta charset="utf-8"/>
#   <meta content="app-id=com.studiosol.player.letras" name="google-play-app"/>
#   <meta content="214701744179" property="fb:pages">
#    <meta content="357922461263649" property="fb:app_id"/>
#    <meta content="telephone=no" name="format-detection"/>
#    <meta content="#FFFFFF" name="theme-color"/>
#    <meta content="async" name="include_mode">
#     <meta content="app-id=773347891" name="apple-itunes-app"/>
#     <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#     <link crossorigin="" href="https://akamai.sscdn.co" rel="preconnect"/>
#     <link href="https://solr.sscdn.co" rel="dns-prefetch"/>
#     <link href="https://tpc.googlesyndication.com" rel="dns-prefetch"/>
#     <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/>
#     <link href="https://pagead2.googlesyndication.com" rel="dns-prefetch"/>
#     <link href="https://prg.smartadserver.com" rel="dns-prefetch"/>
#     <link href="https://fastlane.rubiconproject.com" rel="dns-prefetch"/>
#     <link href="https://htlb.casalemedia.com/" rel="dns-prefetch"/>
#     <link href="http://a9.com/-/spec/opensearch/1.1/" rel="profile"/>
#     <link href="https://akamai.sscdn.co/letras/static/img/favicon.vbc34a3b.ico" rel="icon" type="image/x-icon">
#      <link href="//akamai.sscdn.co/mletras/static/img/apple-touch-icon.v838068f9.png" rel="apple-touch-icon"/>
#      <link href="//akamai.sscdn.co/mletras/static/img/apple-touch-icon.v838068f9.png" rel="apple-touch-icon" sizes="72x72"/>
#      <link href="//akamai.sscdn.co/mletras/static/img/apple-touch-icon.v838068f9.png" rel="apple-touch-icon" sizes="114x114"/>
#      <link href="//akamai.sscdn.co/mletras/static/img/apple-touch-icon.v838068f9.png" rel="apple-touch-icon" sizes="144x144"/>
#      <link as="font" crossorigin="" href="https://akamai.sscdn.co/letras/common/static/font/opensans.woff2" rel="preload" type="font/woff2">
#       <link as="font" crossorigin="" href="https://akamai.sscdn.co/letras/common/static/font/lato.woff2" rel="preload" type="font/woff2">
#        <style>
#         body,h1,h2,h3,p,ol,ul,hr,button{margin:0;padding:0} article,header,section,footer{display:block} html{word-wrap:break-word;overflow-wrap:break-word} body{min-width:980px;padding-top:68px;color:#444;position:relative;background:#fff} input,button,a{outline:none} ul,ol{list-style:none} button{border:0;cursor:pointer} img{border:0;font-size:0} a{text-decoration:none;color:#b7b700} iframe{overflow:hidden} body,input,button{font-style:normal;font-variant:normal;font-weight:normal;font-size:13px;line-height:1;font-family:Arial,sans-serif} h1,h2,h3{font-weight:inherit;font-size:inherit} .g-1{width:1055px;margin:0 auto} .g-2-3{width:695px} .g-1-3{width:335px} .g-1-4,.w-1-4{width:245px} .g-1-5,.w-1-5{width: 191px} .g-1-6{width:155px} @media (max-width:1300px){ .g-1-2,.w-1-2{width:467.5px} .g-1{width:960px} .g-2-3{width:631.66667px} .g-1-3{width:303.33333px} .g-1-4,.w-1-4{width:221.25px} .g-1-5,.w-1-5{width:172px} .g-1-6{width:139.16667px} } .g-1-2,.g-2-3,.g-1-3,.g-1-4,.g-1-5,.g-1-6{float:left;min-height:1px} .g-1-2+.g-1-2,.g-1-3+.g-2-3,.g-2-3+.g-1-3,.g-1-3+.g-1-3,.g-1-4+.g-1-4,.g-1-5+.g-1-5,.g-1-6+.g-1-6{margin-left:25px} .g-1-4:nth-child(4n+1), .g-1-5:nth-child(5n+1){clear:both;margin-left:0} .g-mb{margin-bottom:25px} .g-sp{margin-bottom:50px} .g-pr{position:relative} .g-flex{display:flex} .g-fix::after{content:'';display:block;clear:both;width:100%;height:1px} .hr{height:0;border:0;border-bottom:1px solid #eee;margin-bottom:25px} .hr+.hr{display:none} @media only screen and (max-device-width:1024px) and (min-device-width:768px){ body{width:1020px} } .bt-ouvir,.cnt-more,.bt-b{display:inline-block;line-height:30px;border-radius:6px;font-weight:bold;border:1px solid;cursor:pointer;position:relative;padding:0 12px;font-size:13px} .bt-b,.bt-fa{border-color:#ccc;color:#444;background:#fff} .bt-ouvir{padding:0 15px 0 34px;background:#5eb70b;border-color:#5eb70b;color:#fff} .cnt-more{position:absolute;top:0;right:0;color:#444;border-color:transparent;font-size:15px} .cnt-an-square{width:336px;min-height:250px} .an-full{background:#f5f5f5;position:relative;min-height:90px;z-index:auto} .an-full[data-slotempty="false"],.cnt-an-square[data-slotempty="false"]{display:flex!important;align-items:center;justify-content:center} .an-full div[id*="google_ads_iframe_"],.cnt-an-square div[id*="google_ads_iframe_"]{display:inline} @media (max-width:1300px){ .cnt-an-square{width:300px} .an-full,#pub_10{left:-5px} } #pub_10{height:90px;margin-bottom:25px;display:block} .cnt-space-top{height:115px;overflow:hidden;position:relative} .cnt-space-top::before{content:'';height:90px;position:absolute;top:0;left:0;right:0;background:#f5f5f5} @media only screen and (max-device-width:1024px) and (min-device-width:768px){ .an-full{overflow:hidden} } .an-outpage{position:fixed;left:0;bottom:0} .ps{position:relative;overflow:hidden} .modal{position:absolute;background:#FFF;border:1px solid #ddd;border-radius:12px;box-shadow:rgba(0,0,0,0) 0 1px 3px;visibility:hidden;opacity:0;transition:opacity 0.1s,visibility 0s 0.3s;-webkit-transition:opacity 0.1s,visibility 0s 0.3s;z-index:50} .main-header{height:52px;background:#c2c800;box-shadow:rgba(0,0,0,0.298039) 0 0 10px;position:fixed;top:0;left:0;right:0;z-index:60;transition:all 0.1s;-webkit-transition:all 0.1s} .main-header>div{position:relative} .main-header_logo{height:52px;position:absolute;top:0;left:44px} .main-header_logo a{font-size:0;display:block;width:98px;height:30px;margin:9px 12px} .main-header_logo a::before{content:'';position:absolute;left:0;right:0;top:0;bottom:0} .main-header_bt{position:absolute;top:0;left:0;width:44px;height:52px;font-size:0;background:transparent} .main-search{position:absolute;top:9px;left:50%;margin-left:-262px;width:524px;z-index:30} .main-search_input::-moz-placeholder{color:#CCC;font-weight:normal;opacity:1} .main-search_input::-webkit-input-placeholder{color:#CCC;font-weight:normal;opacity:1} .main-search_input:-ms-input-placeholder{color:#CCC;font-weight:normal;opacity:1} ...
#        </style>
#        <style>
#         .breadcrumb{font-style:normal;font-variant:normal;font-weight:normal;font-size:11px;line-height:1;font-family:Tahoma,sans-serif;color:#ccc;height:36px;text-transform:lowercase;overflow:hidden;position:relative;margin-top:-14px;-webkit-user-select:none} .breadcrumb a{text-decoration:none;padding:10px 22px 10px 0;text-transform:lowercase;display:inline-block;position:relative;color:#ccc;cursor:pointer} .breadcrumb a::after{content:'';position:absolute;width:0;height:0;top:13px;right:6px;border:solid 3px;border-color:#FFF #FFF #FFF #ccc} .breadcrumb>span:last-of-type{cursor:default} .breadcrumb>span:last-of-type a::after{display:none} .h3{font-weight:bold;margin-bottom:15px;color:#b7b700;letter-spacing:-1px;font-size:25px} @media (max-width:1300px){ .h3{font-size:23px} } .h3 a{padding:16px;margin:-16px;display:inline-block;min-width:48px} .h-sep{margin-bottom:15px;border-bottom:3px solid #eee;display:block} .bt-fa{ display:block;position:relative;height:30px;width:30px;font-size:0;border:1px solid #ccc;border-radius:6px} .bt-random{display:flex;align-items:center;width:fit-content;} .bt-random::before{content:'';display:block;width:14px;height:14px;margin-right:8px} .bt-options{font-size:0;width:30px;height:auto;display:flex;align-items:center;justify-content:center;padding:0} .bt-options::before{content:'';display:block;width:16px;height:4px} .cnt-more{position:absolute;top:0;right:0;color:#444;border-color:transparent;font-size:15px} .cnt-more:after{content:" →"} .cnt-head img{border-radius:50%} .cnt-head--a .cnt-head_title{margin-bottom:15px;font-size:0} .cnt-head--a .cnt-head_title img{display:inline-block;vertical-align:middle} .cnt-head--a .cnt-head_title h1{font-size:29px;font-weight:bold;display:inline-block;vertical-align:middle;max-width:550px;padding-left:10px;letter-spacing:-1px} .cnt-head--a h1{color:#b7b700} .cnt-head .bt-b,.cnt-head .bt-fa,.cnt-head .bt-ouvir{margin-right:10px} .cnt-info{position:absolute;top:10px;right:0;text-align:right} .cnt-info .bt-b{margin:0} .cnt-info_contrib,.cnt-info_exib{display:inline-block;vertical-align:baseline} .cnt-info_exib{color:#999;font:11px/1 Tahoma, sans-serif;position:absolute;display: flex;justify-content:flex-end;position:relative;flex-direction:column;margin-bottom:20px} .cnt-info_exib b{font:bold 15px/1 sans-serif;display:block;color:#444;margin-top:2px} .cnt-info_contrib{color:#666} .cnt-info_contrib a{display:inline-block;margin:0 5px;line-height:32px} .cnt-filter{margin-bottom:15px;position:relative} .cnt-filter_tabs{font-size:0} .cnt-filter_tabs>a{border:1px solid #eee;display:inline-block;vertical-align:top;color:#444;font-weight:bold;font-size:15px;line-height:30px;height:30px;padding:0 15px;margin-right:10px;border-radius:16px;text-align:center} .cnt-filter_tabs>a.on{background:#424242;color:#FFF;border:1px solid #424242} @media (max-width:1300px){ .cnt-filter_tabs>a{padding:0 12px;font-size:14px} } .cnt-filter .cnt-filter_form{position:absolute;top:0;right:0} .cnt-filter_form{max-width:36px;background:#FFF;overflow:hidden;height:32px} .cnt-filter_form::after{content:'';position:absolute;top:0;right:100%;width:0;height:100%;transition:width 0.15s;-webkit-transition:width 0.15s} .cnt-filter_form::before{content:'';position:absolute;width:16px;height:16px;top:8px;right:10px} .cnt-filter_form input{font-size:17px;font-weight:700;padding:5px 32px 5px 15px;width:calc(100% - 47px);height:20px;line-height:20px;position:relative;opacity:0;cursor:pointer;border:0;border-radius:8px;z-index:1} .cnt-filter .suggest__drop{top:30px} .cnt-filter_form .suggest__drop{border:0;border-radius:0 0 8px 8px} .cnt-list > li{font-size:15px;position:relative;border-radius:6px} .cnt-list > li > a{padding:6px 10px;display:block;color:#444;font-size:15px;text-decoration:none;line-height:1.4} .cnt-list.-flex-col-2{display:flex;flex-direction:column;height:330px;flex-wrap:wrap;align-content:space-between} .cnt-list.-flex-col-2 > li{width:calc((100% - 25px) / 2)} .cnt-list--num{counter-re ...
#        </style>
#        <link href="//akamai.sscdn.co/letras/static/css/main.va041b5e7.css" media="print" onload="this.media='all'; window.scrollTo(0, 0)" rel="stylesheet"/>
#        <link href="https://www.letras.com/imagine-dragons/mais_acessadas.html" hreflang="es" rel="alternate">
#         <link href="https://www.letras.mus.br/imagine-dragons/mais_acessadas.html" hreflang="pt-br" rel="alternate">
#          <script type="application/ld+json">
#           {"@context":"http://schema.org/","@type":"WebSite","name":"Letras.com","url":"https://www.letras.com/"}
#          </script>
#          <script type="application/ld+json">
#           {"@context":"http://schema.org/","@id":"https://www.letras.com/imagine-dragons/","@type":"MusicGroup","description":"Canciones de Imagine Dragons , artista del estilo Indie","genre":"Indie","image":"https://akamai.sscdn.co/uploadfile/letras/fotos/1/4/8/3/14831730df19f827d1fc7bac7f012a81.jpg","name":"Imagine Dragons","potentialAction":{"@type":"ListenAction","expectsAcceptanceOf":{"@type":"Offer","eligibleRegion":[{"@type":"Country","name":"BR"},{"@type":"Country","name":"US"},{"@type":"Country","name":"AR"},{"@type":"Country","name":"CL"},{"@type":"Country","name":"VE"},{"@type":"Country","name":"EC"},{"@type":"Country","name":"MX"},{"@type":"Country","name":"ES"},{"@type":"Country","name":"UY"}]},"target":[{"@type":"EntryPoint","actionPlatform":["http://schema.org/DesktopWebPlatform","http://schema.org/MobileWebPlatform"],"inLanguage":["pt-BR","en-US","es-ES"],"urlTemplate":"https://www.letras.com/imagine-dragons/ouvir.html"},{"@type":"EntryPoint","actionPlatform":"http://schema.org/AndroidPlatform","inLanguage":["pt-BR","en-US","es-ES"],"urlTemplate":"android-app://com.studiosol.player.letras/http/www.letras.mus.br/imagine-dragons/"}]},"sameAs":["https://www.cifraclub.com/imagine-dragons/"],"track":[{"@context":"http://schema.org/","@id":"https://www.letras.com/imagine-dragons/believer/","@type":"MusicRecording","byArtist":{"@context":"http://schema.org/","@id":"https://www.letras.com/imagine-dragons/","@type":"MusicGroup","description":"Canciones de Imagine Dragons , artista del estilo Indie","genre":"Indie","image":"https://akamai.sscdn.co/uploadfile/letras/fotos/1/4/8/3/14831730df19f827d1fc7bac7f012a81.jpg","name":"Imagine Dragons","potentialAction":{"@type":"ListenAction","expectsAcceptanceOf":{"@type":"Offer","eligibleRegion":[{"@type":"Country","name":"BR"},{"@type":"Country","name":"US"},{"@type":"Country","name":"AR"},{"@type":"Country","name":"CL"},{"@type":"Country","name":"VE"},{"@type":"Country","name":"EC"},{"@type":"Country","name":"MX"},{"@type":"Country","name":"ES"},{"@type":"Country","name":"UY"}]},"target":[{"@type":"EntryPoint","actionPlatform":["http://schema.org/DesktopWebPlatform","http://schema.org/MobileWebPlatform"],"inLanguage":["pt-BR","en-US","es-ES"],"urlTemplate":"https://www.letras.com/imagine-dragons/ouvir.html"},{"@type":"EntryPoint","actionPlatform":"http://schema.org/AndroidPlatform","inLanguage":["pt-BR","en-US","es-ES"],"urlTemplate":"android-app://com.studiosol.player.letras/http/www.letras.mus.br/imagine-dragons/"}]},"sameAs":["https://www.cifraclub.com/imagine-dragons/"],"url":"https://www.letras.com/imagine-dragons/"},"description":"Believer es una canción de Imagine Dragons, artista del estilo Indie","duration":"PT3M25S","genre":"Indie","image":"https://akamai.sscdn.co/uploadfile/letras/fotos/1/4/8/3/14831730df19f827d1fc7bac7f012a81.jpg","inAlbum":{"@context":"http://schema.org/","@id":"https://www.letras.com/imagine-dragons/discografia/live-at-allsaints-studios/","@type":"MusicAlbum","byArtist":{"@id":"https://www.letras.com/imagine-dragons/","@type":"MusicGroup","name":"Imagine Dragons"},"description":"Live at AllSaints Studios es un álbum de Imagine Dragons, artista del estilo Indie","genre":"Indie","image":"https://akamai.sscdn.co/uploadfile/letras/albuns/1/2/1/1/800151571235276.jpg","name":"Live at AllSaints Studios","numtracks":4,"publisher":"","url":"https://www.letras.com/imagine-dragons/discografia/live-at-allsaints-studios/"},"name":"Believer","sameAs":["https://www.cifraclub.com/imagine-dragons/believer/"],"url":"https://www.letras.com/imagine-dragons/believer/"},{"@context":"http://schema.org/","@id":"https://www.letras.com/imagine-dragons/demons/","@type":"MusicRecording","byArtist":{"@context":"http://schema.org/","@id":"https://www.letras.com/imagine-dragons/","@type":"MusicGroup","description":"Canciones de Imagine Dragons , artista del estilo Indie","genre":"Indie","image":"https://akamai.sscdn.co/uploadfile/letras/fotos/1/4/8/3/14831730df19f827d1fc7bac7f0 ...
#          </script>
#          <script type="application/ld+json">
#           {"@context":"http://schema.org/","@id":"https://www.letras.com/","@type":"BreadcrumbList","ItemListElement":[{"@context":"http://schema.org/","@id":"https://www.letras.com/","@type":"ListItem","item":{"@id":"https://www.letras.com/","name":"Página Inicial"},"position":0},{"@context":"http://schema.org/","@id":"https://www.letras.com/estilos/indie/","@type":"ListItem","item":{"@id":"https://www.letras.com/estilos/indie/","name":"Indie"},"position":1},{"@context":"http://schema.org/","@id":"https://www.letras.com/imagine-dragons/","@type":"ListItem","item":{"@id":"https://www.letras.com/imagine-dragons/","name":"Imagine Dragons"},"position":2}]}
#          </script>
#          <meta content="https://akamai.sscdn.co/uploadfile/letras/fotos/1/4/8/3/14831730df19f827d1fc7bac7f012a81.jpg" property="og:image">
#           <meta content="Imagine Dragons" property="og:title">
#            <meta content="https://www.letras.com/imagine-dragons/" property="og:url">
#             <meta content="website" property="og:type"/>
#             <meta content="Letras.com" property="og:site_name"/>
#             <script id="head_scripts_vars">
#              //APS script
#     !function(a9,a,p,s,t,A,g){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(A,g)}("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");
#
#     window.__pageArgs={"action":"all","dns":"imagine-dragons","genre":"indie","isTop1000_es":true,"isTop1000_mx":true,"isTop1000_pt":true,"page":"artist"};
#
#     window.__pageArgs = window.__pageArgs || {};
#     window.__Region = "mx";window.__LocaleLang = "es";window.__Locale = "es_ES";
#     window.__Hash = window.location.hash.replace("#","");
#     window.__IsMobile = false;
#     window.__SafeFrameActive = false;
#     window.disabledAdsense = false;
#     var _plq = _plq || [];var _omq = _omq || [];var _hscmd = _hscmd || [];var googletag = googletag || {};googletag.cmd = googletag.cmd || [];
#     var _adunitSlots = {};var _adunitLazySlots ={};var _adunitDynamicSlots = {};var _adunitRefreshSlots = {};
#     var pbjs = pbjs || {};pbjs.que = pbjs.que || [];pbjs.bidderTimeout = 1300;
#     window._adunitSlots["pub_10_ad"] = {ID:"Letras:728x90:firstView:reload",sizes:[[728,90],[970,90],[970,250],[1055,90],[1055,250]],div:"pub_10_ad",outofpage:false,refresh:false};window._adunitSlots["pub_10_ad_refresh"] = {ID:"Letras:728x90:firstView",sizes:[[728,90],[970,90],[970,250],[1055,90],[1055,250]],div:"pub_10_ad_refresh",outofpage:false,refresh:true};window._adunitSlots["pub_23_ad"] = {ID:"Letras:300x250:top:reload",sizes:[[300,250],[336,280]],div:"pub_23_ad",outofpage:false,refresh:false};window._adunitSlots["pub_23_ad_refresh"] = {ID:"Letras:300x250:top",sizes:[[300,250],[336,280]],div:"pub_23_ad_refresh",outofpage:false,refresh:true};window._adunitSlots["pub_2_ad"] = {ID:"Letras:300x250:footer:reload",sizes:[[320,100],[320,50],[300,100],[300,250],[300,600],[336,280]],div:"pub_2_ad",outofpage:false,refresh:false};window._adunitSlots["pub_2_ad_refresh"] = {ID:"Letras:300x250:footer",sizes:[[320,100],[320,50],[300,100],[300,250],[300,600],[336,280]],div:"pub_2_ad_refresh",outofpage:false,refresh:true};window._adunitSlots["pub_6_ad"] = {ID:"Letras:floatingAds",div:"pub_6_ad",outofpage:true,refresh:false};window._adunitSlots["pub_24_ad"] = {ID:"Letras:728x90:middle:reload",sizes:[[728,90],[970,90],[970,250],[1055,90],[1055,250]],div:"pub_24_ad",outofpage:false,refresh:false};window._adunitSlots["pub_24_ad_refresh"] = {ID:"Letras:728x90:middle",sizes:[[728,90],[970,90],[970,250],[1055,90],[1055,250]],div:"pub_24_ad_refresh",outofpage:false,refresh:true};window._adunitSlots["pub_8_ad"] = {ID:"Letras:bg:internas",div:"pub_8_ad",outofpage:true,refresh:false};window._adunitSlots["pub_9_ad"] = {ID:"Letras:1055x90:billboardInternas:reload",sizes:[[728,90],[970,90],[970,250],[1055,90],[1055,250]],div:"pub_9_ad",outofpage:false,refresh:false};window._adunitSlots["pub_9_ad_refresh"] = {ID:"Letras:1055x90:billboardInternas",sizes:[[728,90],[970,90],[970,250],[1055,90],[1055,250]],div:"pub_9_ad_refresh",outofpage:false,refresh:true};window._adunitSlots["pub_25_ad"] = {ID:"LetrasDesktop:footer:fixed:reload",sizes:[[728,90],[970,90],[1055,90]],div:"pub_25_ad",outofpage:false,refresh:false};window._adunitSlots["pub_25_ad_refresh"] = {ID:"LetrasDesktop:footer:fixed",sizes:[[728,90],[970,90],[1055,90]],div:"pub_25_ad_refresh",outofpage:false,refresh:true};
#     var prebidAdUnits = [{"code":"pub_10_ad","mediaTypes":{"banner":{"sizes":[[728,90],[970,90],[1055,90]]}},"bids":[{"id":"yahoossp-8a969457017575d60376d79fe424003f-letras_728x90_firstview_reload","bidder":"yahoossp","params":{"dcn":"8a969457017575d60376d79fe424003f","pos":"letras_728x90_firstview_reload"}},{"id":"appnexus-13893938","bidder":"appnexus","params":{"placementId":"13893938"}},{"id":"rubicon-14458-101116-1046420","bidder":"rubicon","params":{"accountId":"14458","siteId":"101116","zoneId":"1046420"}},{"id":"smartadserver-69269","bidder":"smartadserver","params":{"domain":"https://prg.smartadserver.com","formatId":"69269","pageId":887594,"siteId":202484}},{"id":"ix-376640","bidder":"ix","labelAny":["AllowedIX"],"params":{"siteId":"376640"}},{"id":"eplanning","bidder":"eplanning","params":{"ci":"58f00"}}]},{"code":"pub_23_ad","mediaTypes":{"banner":{"sizes":[[300,250],[336,280]]}},"bids":[{"id":"yahoossp-8a969457017575d60376d79fe424003f-letras_300x250_top_reload","bidder":"yahoossp","params":{"dcn":"8a969457017575d60376d79fe424003f","pos":"letras_300x250_top_reload"}},{"id":"appnexus-14344925","bidder":"appnexus","params":{"placementId":"14344925"}},{"id":"rubicon-14458-101116-1073054","bidder":"rubicon","params":{"accountId":"14458","siteId":"101116","zoneId":"1073054"}},{"id":"smartadserver-70175","bidder":"smartadserver","params":{"domain":"https://prg.smartadserver.com","formatId":"70175","pageId":887594,"siteId":202484}},{"id":"ix-376644","bidder":"ix","labelAny":["AllowedIX"],"params":{"siteId":"376644"}},{"id":"eplanning","bidder":"eplanning","params":{"ci":"58f00"}}]},{"code":"pub_2_ad","mediaTypes":{"banner":{"sizes":[[320,100],[320,50],[300,100],[300,250],[300,600],[336,280]]}},"bids":[{"id":"yahoossp-8a969457017575d60376d79fe424003f-letras_300x250_footer_reload","bidder":"yahoossp","params":{"dcn":"8a969457017575d60376d79fe424003f","pos":"letras_300x250_footer_reload"}},{"id":"appnexus-13893896","bidder":"appnexus","params":{"placementId":"13893896"}},{"id":"rubicon-14458-101116-1051464","bidder":"rubicon","params":{"accountId":"14458","siteId":"101116","zoneId":"1051464"}},{"id":"smartadserver-69263","bidder":"smartadserver","params":{"domain":"https://prg.smartadserver.com","formatId":"69263","pageId":887594,"siteId":202484}},{"id":"ix-376645","bidder":"ix","labelAny":["AllowedIX"],"params":{"siteId":"376645"}},{"id":"eplanning","bidder":"eplanning","params":{"ci":"58f00"}}]},{"code":"pub_24_ad","mediaTypes":{"banner":{"sizes":[[728,90],[970,90],[970,250],[1055,90],[1055,250]]}},"bids":[{"id":"yahoossp-8a969457017575d60376d79fe424003f-letras_728x90_middle_reload","bidder":"yahoossp","params":{"dcn":"8a969457017575d60376d79fe424003f","pos":"letras_728x90_middle_reload"}},{"id":"appnexus-14155112","bidder":"appnexus","params":{"placementId":"14155112"}},{"id":"rubicon-14458-101116-1079488","bidder":"rubicon","params":{"accountId":"14458","siteId":"101116","zoneId":"1079488"}},{"id":"smartadserver-70348","bidder":"smartadserver","params":{"domain":"https://prg.smartadserver.com","formatId":"70348","pageId":887594,"siteId":202484}},{"id":"ix-376639","bidder":"ix","labelAny":["AllowedIX"],"params":{"siteId":"376639"}},{"id":"eplanning","bidder":"eplanning","params":{"ci":"58f00"}}]},{"code":"pub_9_ad","mediaTypes":{"banner":{"sizes":[[728,90],[970,90],[970,250],[1055,90],[1055,250]]}},"bids":[{"id":"yahoossp-8a969457017575d60376d79fe424003f-letras_1055x90_billboardinternas_reload","bidder":"yahoossp","params":{"dcn":"8a969457017575d60376d79fe424003f","pos":"letras_1055x90_billboardinternas_reload"}},{"id":"appnexus-13893937","bidder":"appnexus","params":{"placementId":"13893937"}},{"id":"rubicon-14458-101116-1046438","bidder":"rubicon","params":{"accountId":"14458","siteId":"101116","zoneId":"1046438"}},{"id":"smartadserver-69268","bidder":"smartadserver","params":{"domain":"https://prg.smartadserver.com","formatId":"69268","pageId":887594,"siteId":202484}},{"id":"ix-376647","bidder":"ix","labelAny":["Allowed ...
# 	var __activeBids = ["rubicon","smartadserver","ix","eplanning","yahoossp","appnexus"];
#     _hscmd.push(function() {initADPipeline();});
#             </script>
#             <link href="https://www.letras.com/opensearchdescription.xml" rel="search" title="Búsqueda de letras" type="application/opensearchdescription+xml">
#              <link href="/destaques.rss" rel="alternate" title="RSS Feed - Destacados - Letras.com" type="application/rss+xml">
#               <link href="/destaques.atom" rel="alternate" title="Atom Feed - Destacados - Letras.com" type="application/atom+xml">
#                <link href="/playlists.rss" rel="alternate" title="RSS Feed - Playlists - Letras.com" type="application/rss+xml">
#                 <link href="/playlists.atom" rel="alternate" title="Atom Feed - Playlists - Letras.com" type="application/atom+xml">
#                  <link href="/blog.rss" rel="alternate" title="RSS Feed - Blog - Letras.com" type="application/rss+xml">
#                   <link href="/manifest.json" rel="manifest"/>
#                   <script>
#                    if (!("Promise" in window)) {
# 		document.write('<script src="//akamai.sscdn.co/letras/common/static/js/promise.vd6adfb0c.js"><\/script>');
# 	}
#                   </script>
#                  </link>
#                 </link>
#                </link>
#               </link>
#              </link>
#             </link>
#            </meta>
#           </meta>
#          </meta>
#         </link>
#        </link>
#       </link>
#      </link>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body class="es-es" data-locale="es-es">
#   <script type="text/javascript">
#    if(window.document.cookie.match(new RegExp("lasub=([^;][A-Za-z0-9]{2,5})"))){document.body.classList.add("has-subscription");}
#   </script>
#   <div class="wrapper">
#    <header class="main-header g-mb">
#     <div class="g-1">
#      <h2 class="main-header_logo">
#       <a href="/">
#        LETRAS.COM - Letras de canciones
#       </a>
#      </h2>
#      <button class="main-header_bt">
#       menu
#      </button>
#      <form class="main-search suggest">
#       <label>
#        <input aria-label="¿Qué quieres escuchar ahora?" autocomplete="off" class="main-search_input" id="main_suggest" placeholder="¿Qué quieres escuchar ahora?"/>
#       </label>
#       <button class="main-search_submit" title="buscar">
#        buscar
#       </button>
#       <div class="suggest__drop modal">
#        <ul class="suggest__list">
#        </ul>
#        <div class="suggest__all">
#        </div>
#       </div>
#      </form>
#      <div class="main-header_ccid">
#       <span id="js-user-send">
#       </span>
#       <span id="js-user-menu">
#       </span>
#      </div>
#     </div>
#    </header>
#    <div class="page-artist" id="all">
#     <div id="cnt_top">
#      <div class="breadcrumb cor_1 g-1" id="breadcrumb" itemscope="" itemtype="http://schema.org/BreadcrumbList">
#       <span itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#        <a href="/" itemprop="item">
#         <span itemprop="name">
#          Página Inicial
#         </span>
#        </a>
#        <meta content="1" itemprop="position"/>
#       </span>
#       <span itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#        <a href="/estilos/indie/" itemprop="item">
#         <span itemprop="name">
#          Indie
#         </span>
#        </a>
#        <meta content="2" itemprop="position"/>
#       </span>
#       <span itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#        <a href="/imagine-dragons/" itemprop="item">
#         <span itemprop="name">
#          Imagine Dragons
#         </span>
#        </a>
#        <meta content="3" itemprop="position"/>
#       </span>
#      </div>
#      <div class="an-outpage an-pub" id="pub_6" style="display:block;">
#       <div id="pub_6_ad">
#       </div>
#      </div>
#      <div class="an-outpage an-pub" id="pub_8" style="display:block;">
#       <div id="pub_8_ad">
#       </div>
#      </div>
#      <div class="cnt-artista g-mb">
#       <div class="cnt-space-top g-1">
#        <div class="an-full g-1 g-mb with-refresh an-pub" data-intersectionratio="0.40" data-refresh="15" id="pub_10" style="display:block;">
#         <div id="pub_10_ad_refresh">
#          <div id="pub_10_ad">
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="cnt-head cnt-head--a g-mb g-1 g-pr">
#        <div class="cnt-head_title">
#         <a href="/imagine-dragons/">
#          <img alt="" height="44" src="https://akamai.sscdn.co/uploadfile/letras/fotos/1/4/8/3/14831730df19f827d1fc7bac7f012a81-tb2.jpg" srcset="https://akamai.sscdn.co/uploadfile/letras/fotos/1/4/8/3/14831730df19f827d1fc7bac7f012a81-tb2.jpg 1x, https://akamai.sscdn.co/uploadfile/letras/fotos/1/4/8/3/14831730df19f827d1fc7bac7f012a81-tb.jpg 2x" title="Imagine Dragons" width="44"/>
#          <h1>
#           Imagine Dragons
#          </h1>
#         </a>
#        </div>
#        <div class="g-flex">
#         <a class="bt-ouvir" data-art-action="Click Botão Ouvir" data-art-label="Cabeçalho" data-nofollow="true" href="/imagine-dragons/ouvir.html" rel="nofollow" title="Más reproducidas de Imagine Dragons">
#          Escuchar
#         </a>
#         <a class="bt-b bt-random" data-art-action="Click Botão Aleatório" data-art-label="Cabeçalho" href="/imagine-dragons/ouvir_aleatorio.html" rel="nofollow">
#          <span>
#           Aleatorio
#          </span>
#         </a>
#         <div class="js-ajax-include" data-need-login="1" data-src="/artist/135099/favorite.ssi?dns=imagine-dragons" style="display:inline;">
#          <a class="bt-fa" data-activetext="" data-id="135099" data-name="artist" data-params="dns=imagine-dragons" data-text="Añadir a favoritos" href="javascript:;" title="Añadir a favoritos">
#           Añadir a favoritos
#          </a>
#         </div>
#         <div class="cnt-head-modal">
#          <button class="bt-options bt-b" data-art-action="Click Botão Overflow" data-art-label="Cabeçalho">
#           Opciones
#          </button>
#          <div class="cnt-list-options-modal -spaced -header">
#           <ol class="cnt-list-options-list">
#            <li>
#             <a class="cnt-list-option -link" data-art-action="Click Ir Para Rádio" data-art-label="Cabeçalho (Overflow)" href="/imagine-dragons/radio.html" rel="nofollow">
#              Ir a la radio del artista
#             </a>
#            </li>
#           </ol>
#           <ol class="cnt-list-options-list -share">
#            <li class="cnt-list-option">
#             <div>
#              <span>
#               Compartir
#              </span>
#              <div class="sh-container">
#               <div class="sh js-share-playlist">
#                <a class="sh-bt sh-f" data-art-action="Click Share Facebook" data-art-label="Cabeçalho (Overflow)" data-nofollow="true" href='http://www.facebook.com/sharer.php?u=https://www.letras.com%2Fimagine-dragons%2F"e=Imagine+Dragons%20en%20Letras' rel="nofollow" title="Facebook">
#                 Facebook
#                </a>
#                <a class="sh-bt sh-t" data-art-action="Click Share Twitter" data-art-label="Cabeçalho (Overflow)" data-nofollow="true" href="http://twitter.com/share?url=https://www.letras.com%2Fimagine-dragons%2F&amp;related=letras&amp;text=%E2%99%AB%20Imagine+Dragons%20en%20@letras" rel="nofollow" title="Twitter">
#                 Twitter
#                </a>
#               </div>
#               <div class="sh-link" data-art-action="Click Copiar Link" data-art-label="Cabeçalho (Overflow)" data-share="https://www.letras.com/imagine-dragons/" title="Copiar vínculo">
#                Copiar vínculo
#               </div>
#              </div>
#             </div>
#            </li>
#           </ol>
#          </div>
#         </div>
#        </div>
#        <div class="cnt-info">
#         <div class="cnt-info_exib">
#          vistas
#          <b>
#           2.402.275
#          </b>
#         </div>
#         <a class="bt-b" data-ct-action="Nav Enviar Contribuição" data-ct-label="Below Social (artist)" href="/contribuicoes/enviar_letra/imagine-dragons/">
#          <strong>
#           Enviar letras, traducciones y más
#          </strong>
#         </a>
#        </div>
#       </div>
#       <hr class="hr"/>
#       <div class="g-1 g-fix g-pr">
#        <div class="g-2-3">
#         <div class="cnt-filter">
#          <h2 class="h3">
#           Más reproducidas
#          </h2>
#          <form class="cnt-filter_form suggest w-1-4">
#           <input aria-label="Filtrar" autocomplete="off" data-dns="imagine-dragons" id="inletra" type="text"/>
#           <div class="suggest__drop modal">
#            <ul class="suggest__list">
#            </ul>
#           </div>
#          </form>
#         </div>
#         <i class="h-sep">
#         </i>
#         <div class="list-container">
#          <div class="list-overlay">
#          </div>
#          <ul class="cnt-list-songs -counter -top-songs js-song-list">
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="2876080" data-name="Believer" data-sharetext="Believer de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/believer/" data-url="believer">
#            <a class="song-name" href="/imagine-dragons/believer/">
#             <span>
#              Believer
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="2079976" data-name="Demons" data-sharetext="Demons de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/demons/" data-url="demons">
#            <a class="song-name" href="/imagine-dragons/demons/">
#             <span>
#              Demons
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="3075920" data-name="Bad Liar" data-sharetext="Bad Liar de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/bad-liar/" data-url="bad-liar">
#            <a class="song-name" href="/imagine-dragons/bad-liar/">
#             <span>
#              Bad Liar
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="3603744" data-name="Bones" data-sharetext="Bones de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/bones/" data-url="bones">
#            <a class="song-name" href="/imagine-dragons/bones/">
#             <span>
#              Bones
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="2804853" data-name="Not Today" data-sharetext="Not Today de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/not-today/" data-url="not-today">
#            <a class="song-name" href="/imagine-dragons/not-today/">
#             <span>
#              Not Today
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="3026712" data-name="Natural" data-sharetext="Natural de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/natural/" data-url="natural">
#            <a class="song-name" href="/imagine-dragons/natural/">
#             <span>
#              Natural
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="2898106" data-name="Thunder" data-sharetext="Thunder de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/thunder/" data-url="thunder">
#            <a class="song-name" href="/imagine-dragons/thunder/">
#             <span>
#              Thunder
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="2091848" data-name="Radioactive" data-sharetext="Radioactive de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/radioactive/" data-url="radioactive">
#            <a class="song-name" href="/imagine-dragons/radioactive/">
#             <span>
#              Radioactive
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="3412436" data-name="Enemy (feat. J.I.D)" data-sharetext="Enemy (feat. J.I.D) de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/enemy/" data-url="enemy">
#            <a class="song-name" href="/imagine-dragons/enemy/">
#             <span>
#              Enemy (feat. J.I.D)
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="2900823" data-name="Whatever It Takes" data-sharetext="Whatever It Takes de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/whatever-it-takes/" data-url="whatever-it-takes">
#            <a class="song-name" href="/imagine-dragons/whatever-it-takes/">
#             <span>
#              Whatever It Takes
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="2167788" data-name="Nothing Left To Say" data-sharetext="Nothing Left To Say de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/nothing-left-to-say-rocks/" data-url="nothing-left-to-say-rocks">
#            <a class="song-name" href="/imagine-dragons/nothing-left-to-say-rocks/">
#             <span>
#              Nothing Left To Say
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="3076535" data-name="Birds" data-sharetext="Birds de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/birds/" data-url="birds">
#            <a class="song-name" href="/imagine-dragons/birds/">
#             <span>
#              Birds
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="2707921" data-name="Dream" data-sharetext="Dream de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/dream/" data-url="dream">
#            <a class="song-name" href="/imagine-dragons/dream/">
#             <span>
#              Dream
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="1972810" data-name="It's Time" data-sharetext="It's Time de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/1972810/" data-url="1972810">
#            <a class="song-name" href="/imagine-dragons/1972810/">
#             <span>
#              It's Time
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="2981171" data-name="Next To Me" data-sharetext="Next To Me de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/next-to-me/" data-url="next-to-me">
#            <a class="song-name" href="/imagine-dragons/next-to-me/">
#             <span>
#              Next To Me
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="2818347" data-name="Sucker For Pain (feat. Wiz Khalifa, Lil Wayne, Logic, Ty Dolla $ign And X Ambassadors)" data-sharetext="Sucker For Pain (feat. Wiz Khalifa, Lil Wayne, Logic, Ty Dolla $ign And X Ambassadors) de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/sucker-for-pain/" data-url="sucker-for-pain">
#            <a class="song-name" href="/imagine-dragons/sucker-for-pain/">
#             <span>
#              Sucker For Pain (feat. Wiz Khalifa, Lil Wayne, Logic, Ty Dolla $ign And X Ambassadors)
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="3647352" data-name="Sharks" data-sharetext="Sharks de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/sharks/" data-url="sharks">
#            <a class="song-name" href="/imagine-dragons/sharks/">
#             <span>
#              Sharks
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="2108737" data-name="On Top Of The World" data-sharetext="On Top Of The World de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/on-top-of-the-world/" data-url="on-top-of-the-world">
#            <a class="song-name" href="/imagine-dragons/on-top-of-the-world/">
#             <span>
#              On Top Of The World
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="2671856" data-name="Warriors" data-sharetext="Warriors de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/warriors/" data-url="warriors">
#            <a class="song-name" href="/imagine-dragons/warriors/">
#             <span>
#              Warriors
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="2692741" data-name="I'm So Sorry" data-sharetext="I'm So Sorry de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/im-so-sorry/" data-url="im-so-sorry">
#            <a class="song-name" href="/imagine-dragons/im-so-sorry/">
#             <span>
#              I'm So Sorry
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="3076461" data-name="Only" data-sharetext="Only de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/only/" data-url="only">
#            <a class="song-name" href="/imagine-dragons/only/">
#             <span>
#              Only
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="3501384" data-name="Wrecked" data-sharetext="Wrecked de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/wrecked/" data-url="wrecked">
#            <a class="song-name" href="/imagine-dragons/wrecked/">
#             <span>
#              Wrecked
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="2693037" data-name="Shots" data-sharetext="Shots de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/shots/" data-url="shots">
#            <a class="song-name" href="/imagine-dragons/shots/">
#             <span>
#              Shots
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="3076384" data-name="West Coast" data-sharetext="West Coast de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/west-coast/" data-url="west-coast">
#            <a class="song-name" href="/imagine-dragons/west-coast/">
#             <span>
#              West Coast
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="3076433" data-name="Love" data-sharetext="Love de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/love/" data-url="love">
#            <a class="song-name" href="/imagine-dragons/love/">
#             <span>
#              Love
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="2568055" data-name="Monster" data-sharetext="Monster de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/monster/" data-url="monster">
#            <a class="song-name" href="/imagine-dragons/monster/">
#             <span>
#              Monster
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="3100218" data-name="Believer (remix) (feat. Lil Wayne)" data-sharetext="Believer (remix) (feat. Lil Wayne) de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/believer-remix-feat-lil-wayne/" data-url="believer-remix-feat-lil-wayne">
#            <a class="song-name" href="/imagine-dragons/believer-remix-feat-lil-wayne/">
#             <span>
#              Believer (remix) (feat. Lil Wayne)
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="3573984" data-name="Enemy (Solo Mix)" data-sharetext="Enemy (Solo Mix) de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/enemy-solo-mix/" data-url="enemy-solo-mix">
#            <a class="song-name" href="/imagine-dragons/enemy-solo-mix/">
#             <span>
#              Enemy (Solo Mix)
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
#           <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="3125094" data-name="Mad World" data-sharetext="Mad World de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/mad-world/" data-url="mad-world">
#            <a class="song-name" href="/imagine-dragons/mad-world/">
#             <span>
#              Mad World
#             </span>
#            </a>
#            <div class="song-options">
#            </div>
#           </li>
# ...
#         </b>
#        </span>
#       </a>
#      </div>
#      <div class="g-1-2">
#       <strong>
#        Plugins
#       </strong>
#       <a class="footer_apps_ch" href="/plugin/chrome/">
#        <i>
#        </i>
#        <span>
#         Plugin
#         <b>
#          Chrome
#         </b>
#        </span>
#       </a>
#       <a class="footer_apps_mp" href="/plugin/windows/">
#        <i>
#        </i>
#        <span>
#         Windows
#         <b>
#          Media Player
#         </b>
#        </span>
#       </a>
#       <a class="footer_apps_wn" href="/plugin/windows/">
#        <i>
#        </i>
#        <span>
#         Windows
#         <b>
#          Winamp
#         </b>
#        </span>
#       </a>
#      </div>
#     </div>
#     <hr/>
#     <div class="footer_social g-fix">
#      <div class="g-1-2">
#       <strong>
#        Sigue a Letras
#       </strong>
#       <div class="footer_follows">
#        <a class="footer_follow -youtube" href="https://www.youtube.com/letrasmusbr" rel="noopener" target="_blank">
#         <i>
#         </i>
#         <span>
#          YouTube
#         </span>
#        </a>
#        <a class="footer_follow -tiktok" href="https://www.tiktok.com/@letras" rel="noopener" target="_blank">
#         <i>
#         </i>
#         <span>
#          TikTok
#         </span>
#        </a>
#        <a class="footer_follow -pinterest" href="https://br.pinterest.com/letrasmusbr" rel="noopener" target="_blank">
#         <i>
#         </i>
#         <span>
#          Pinterest
#         </span>
#        </a>
#        <a class="footer_follow -twitter" href="https://twitter.com/letras" rel="noopener" target="_blank">
#         <i>
#         </i>
#         <span>
#          Twitter
#         </span>
#        </a>
#        <a class="footer_follow -instagram" href="https://www.instagram.com/letrasmusbr/" rel="noopener" target="_blank">
#         <i>
#         </i>
#         <span>
#          Instagram
#         </span>
#        </a>
#        <a class="footer_follow -facebook" href="https://facebook.com/letraslatam" rel="noopener" target="_blank">
#         <i>
#         </i>
#         <span>
#          Facebook
#         </span>
#        </a>
#       </div>
#      </div>
#      <div class="footer_lang g-1-2">
#       <strong>
#        Idiomas
#       </strong>
#       <a class="footer_lang_en rdp-lang-en js-locale-select" data-locale="en_US" data-nofollow="true" href="https://www.letras.com/?locale=en_US" rel="nofollow">
#        English
#       </a>
#       <a class="footer_lang_pt rdp-lang-pt js-locale-select" data-locale="pt_BR" data-nofollow="true" href="https://www.letras.com/?locale=pt_BR">
#        Português
#       </a>
#      </div>
#     </div>
#     <hr/>
#     <div class="footer_ss">
#      <p>
#       Música comienza con letras
#       <br/>
#       © 2003 - 2022, 3.1 millones de canciones
#       <br/>
#       Hecho con
#       <b>
#        amor
#       </b>
#       en Belo Horizonte - Brasil
#      </p>
#      <div>
#       <span>
#        Más música en:
#       </span>
#       <a class="footer_ss_c" href="https://www.cifraclub.com/">
#        Cifra Club
#       </a>
#       <a class="footer_ss_p" href="https://www.palcomp3.com/">
#        Palco MP3
#       </a>
#      </div>
#     </div>
#     <div class="footer_partners">
#      <p>
#       Asociados:
#      </p>
#      <div class="footer_partners_links">
#       <a class="footer_partners_ss" href="https://www.studiosol.com.br/?lang=es" rel="noopener" target="_blank">
#        Studio Sol
#       </a>
#      </div>
#     </div>
#     <div class="g-pr">
#      <i class="footer_museu" title="Museo de Artes y Oficios">
#      </i>
#      <i class="footer_igreja" title="Iglesia de San Francisco de Asís">
#      </i>
#      <i class="footer_praca" title="Obelisco de la plaza Siete de Septiembre">
#      </i>
#     </div>
#    </div>
#   </footer>
#   <div class="menu modal" id="js-main-menu-modal">
#    <div class="m_rail">
#    </div>
#    <div class="m_tabs">
#     <ul>
#      <li>
#       <a class="on" data-tab="m_musicas" href="/mais-acessadas/" id="js-music-tab">
#        Canciones
#       </a>
#      </li>
#      <li>
#       <a data-tab="m_artistas" href="/mais-acessadas/">
#        Artistas
#       </a>
#      </li>
#      <li>
#       <a data-tab="m_estilos" href="/estilos/">
#        Géneros musicales
#       </a>
#      </li>
#      <li>
#       <a data-tab="m_playlists" href="/playlists.html">
#        Playlists
#       </a>
#      </li>
#      <li>
#       <a data-tab="m_dicionario" href="/academy/dicionario/">
#        Diccionario
#       </a>
#      </li>
#      <li>
#       <a data-tab="m_apps" href="#">
#        Aplicaciones
#       </a>
#      </li>
#     </ul>
#     <a data-ct-action="Nav Enviar Letra" data-ct-label="Menu (topo)" href="/contribuicoes/enviar_letra/" rel="nofollow">
#      Enviar letra
#     </a>
#    </div>
#    <div class="m_cnt m_musicas on" data-endpoint="songs">
#    </div>
#    <div class="m_cnt m_artistas" data-endpoint="artists">
#    </div>
#    <div class="m_cnt m_estilos" data-endpoint="genres">
#    </div>
#    <div class="m_cnt m_playlists" data-endpoint="playlists">
#    </div>
#    <div class="m_cnt m_dicionario" data-endpoint="dictionary">
#    </div>
#    <div class="m_cnt m_apps" data-endpoint="" data-loaded="1">
#     <div class="m_title">
#      Aplicaciones y plugins
#     </div>
#     <div class="mapp_m">
#      <i>
#       Teléfono móvil
#      </i>
#      <a class="mapp_m_g" href="https://play.google.com/store/apps/details?id=com.studiosol.player.letras" rel="noopener" target="_blank">
#       Android
#      </a>
#      <a class="mapp_m_a" href="https://itunes.apple.com/br/app/letras.mus.br/id773347891?mt=8" rel="noopener" target="_blank">
#       iPhone
#      </a>
#      <a class="mapp_m_w" href="https://www.microsoft.com/es-es/p/letrasmusbr/9wzdncrfj180/" rel="noopener" target="_blank">
#       Windows Phone
#      </a>
#     </div>
#     <div class="mapp_d">
#      <i>
#       Desktop
#      </i>
#      <a class="mapp_d_g" href="/plugin/chrome/">
#       Google Chrome
#      </a>
#      <a class="mapp_d_w" href="https://www.microsoft.com/es-es/p/letrasmusbr/9wzdncrfj184/" rel="noopener" target="_blank">
#       Windows 8
#      </a>
#     </div>
#     <div class="mapp_p">
#      <i>
#       Plugin
#      </i>
#      <a class="mapp_p_m" href="/plugin/windows/">
#       W. Media Player
#      </a>
#      <a class="mapp_p_w" href="/plugin/windows/">
#       Winamp
#      </a>
#     </div>
#    </div>
#   </div>
#   <div class="user modal" id="js-user-menu-modal">
#    <div class="m_rail">
#    </div>
#    <div class="u_links">
#     <ul>
#      <li>
#       <a href="#" id="js-meu-perfil">
#        Mi perfil
#       </a>
#      </li>
#      <li>
#       <a data-ct-action="Nav Enviar Letra" data-ct-label="Menu User (topo)" href="/contribuicoes/">
#        Enviar letra
#       </a>
#      </li>
#      <li>
#       <a href="#" id="js-user-mensagens">
#        Mensajes
#       </a>
#      </li>
#      <li>
#       <a href="https://accounts.letras.com/editar/" rel="noopener" target="_blank">
#        Editar
#       </a>
#      </li>
#      <li>
#       <a href="https://accounts.letras.com/logout/" id="js-logout">
#        Salir
#       </a>
#      </li>
#     </ul>
#     <label class="user-localeSelector" id="region-selector">
#      <span class="user-localeSelector-label">
#       Ubicación:
#      </span>
#      <button class="user-localeSelector-button">
#      </button>
#      <span class="user-localeSelector-menu">
#      </span>
#     </label>
#     <label class="user-localeSelector" id="language-selector">
#      <span class="user-localeSelector-label">
#       Idioma:
#      </span>
#      <button class="user-localeSelector-button">
#      </button>
#      <span class="user-localeSelector-menu">
#      </span>
#     </label>
#    </div>
#    <div class="user_wrap">
#     <div class="user_tabs cnt-filter">
#      <div class="cnt-filter_tabs" id="user_tabs">
#       <a data-tab="u_playlists" href="#">
#        Playlists
#       </a>
#       <a data-tab="u_artistas" href="#">
#        Artistas
#       </a>
#       <a data-tab="u_albuns" href="#">
#        Álbumes
#       </a>
#       <a data-tab="u_notificacoes" href="#">
#        Notificaciones
#        <span class="js-n-n">
#        </span>
#       </a>
#       <a data-tab="u_amigos" href="#">
#        Amigos pendientes
#        <span class="js-fr-n">
#        </span>
#       </a>
#      </div>
#     </div>
#     <div class="u_cnt u_playlists" data-endpoint="playlists">
#      <div class="user-playlists-list on ps">
#       <ul class="pl_list user-playlists-default -owner" id="ccid_playlist-list">
#       </ul>
#      </div>
#      <div class="user-playlistSongs-list ps">
#       <div class="user-playlistSongs-header" id="js-playlist-header">
#        <button class="user-playlistSongs-return" id="js-playlist-return">
#        </button>
#        <b class="user-playlistSongs-title">
#        </b>
#        <button class="u_playlists_listen bt-ouvir" data-title="Ouvir" id="js-user-menu-listen">
#         Escuchar
#        </button>
#       </div>
#       <ul class="pl_list pl_list--num playlistSongs-items" id="ccid_playlist-view">
#       </ul>
#      </div>
#     </div>
#     <div class="u_cnt u_artistas" data-endpoint="artists">
#     </div>
#     <div class="u_cnt u_albuns" data-endpoint="albums">
#     </div>
#     <div class="u_cnt u_notificacoes" data-endpoint="notifications">
#      <div class="ps">
#       <p style="display: none;">
#        Quiero recibir notificaciones de artistas destacados y noticias.
#        <span class="bt-toggle" id="js-toggle-push">
#        </span>
#       </p>
#       <ul class="js-nt-list nt_list">
#       </ul>
#      </div>
#     </div>
#     <div class="u_cnt u_amigos" data-endpoint="friends">
#      <div class="ps js-fr-not">
#       <ul class="list ccid_notify_am">
#       </ul>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script id="user_widget_send_template" type="text/template">
#    <a rel="nofollow" href="/contribuicoes/">Enviar letra</a>
#   </script>
#   <script id="user_widget_template" type="text/template">
#    <a class="js-user-open-login" href="#">Entrar</a>
#   </script>
#   <script id="user_widget_auth_template" type="text/template">
#    <a href="/membros/<%- id %>/" class="main-header_user"> <%- nickname %> <img src="<%- avatar %>" width="32" height="32" alt=""> <i class="unread_notifications" style="display:none" alt=""></i> </a>
#   </script>
#   <script id="notification_fr_template" type="text/template">
#    <li data-userid="<%- userID %>" data-id="<%- id %>" class="<%- !seen ? 'ccid_new' : ''%>"> <a class="js-user-notification" href="/membros/<%- userID %>/"> <img data-original="<%- userAvatar %>" data-lazy="true" alt="" width="32" height="32"> <b><%- userName %></b> </a> <button data-type="ignore" class="js-decline ccid_notify_ig">Ignorar</button> <button data-type="confirm" class="js-confirm ccid_notify_ac">Aceptar</button> </li>
#   </script>
#   <script id="widget_playlists_template" type="text/template">
#    <li class="user-playlists-item"> <span id="js-user-menu-listen" data-endpoint="<%- endpoint %>" data-credentials="<%- credentials %>" class="user-playlists-play"></span> <a href="#" data-endpoint="<%- endpoint %>" data-credentials="<%- credentials %>"> <span><%- name %></span> </a> <button class="bt-b-s plt_edit user-playlist-edit" data-hash="<%- hash %>" data-endpoint="<%- endpoint %>" data-credentials="<%- credentials %>">editar</button> </li>
#   </script>
#   <script id="widget_songs_template" type="text/template">
#    <li> <a href="<%- '/'+dns+'/'+url+'/#'+hash %>"> <span class="bt-play"></span> <p><%- artist %> - <span><%- name %></span></p> </a> </li>
#   </script>
#   <div class="modal edit-playlist" id="edit-playlist">
#    <div class="edit-playlist_cnt">
#     <span class="h3">
#      Editar playlist
#     </span>
#     <div class="h-sep">
#     </div>
#     <div class="ep_confirm ep_confirm_del">
#      <span>
#       ¿Seguro quieres eliminar esta playlist?
#      </span>
#      <button class="ep_del_n">
#       Cancelar
#      </button>
#      <button class="ep_del_y">
#       Eliminar
#      </button>
#     </div>
#     <div class="ep_confirm ep_confirm_close">
#      <span>
#       ¿Seguro quieres salir sin guardar los cambios que hiciste?
#      </span>
#      <button class="ep_close_n">
#       Cancelar
#      </button>
#      <button class="ep_close_y">
#       Salir sin guardar
#      </button>
#     </div>
#     <div class="ep_actions">
#      <button class="ep_delete">
#       Eliminar playlist
#      </button>
#      <button class="bt-b ep_cancel">
#       Cancelar
#      </button>
#      <button class="bt-x ep_save">
#       Guardar
#      </button>
#     </div>
#     <form class="edit-playlist-form">
#      <div class="ep_name">
#       <label class="label">
#        Nombre
#       </label>
#       <input class="ep_name_input input js-name" value=""/>
#       <span class="ep_name_counter js-name-counter">
#       </span>
#      </div>
#      <div class="ep_visibility">
#       <label class="label">
#        Quién puede escuchar esta lista
#       </label>
#       <div>
#        <label class="chk">
#         <input checked="" name="visibility" type="radio" value="public"/>
#         <span>
#          Todos
#         </span>
#        </label>
#        <label class="chk">
#         <input checked="" name="visibility" type="radio" value="me"/>
#         <span>
#          Solo yo
#         </span>
#        </label>
#       </div>
#      </div>
#      <hr class="line"/>
#      <div class="s_form">
#       <label class="label">
#        Añadir canción
#       </label>
#       <div class="suggest">
#        <input autocomplete="off" class="s_input input" id="edit-playlist_suggest" placeholder="¿Qué canción quieres añadir?"/>
#        <div class="suggest__drop modal">
#         <ul class="cnt-list-check">
#         </ul>
#        </div>
#       </div>
#      </div>
#     </form>
#     <div class="ep_results ps">
#      <ul class="cnt-list sortable">
#      </ul>
#     </div>
#    </div>
#   </div>
#   <div class="modal_overlay js-edit-playlist-overlay">
#   </div>
#   <script id="edit_playlist_list_item" type="text/template">
#    <li data-lid="<%- id %>" data-id="<%- playlistSongID %>"> <span class="select-order"> <select> <option><%- index %></option> </select> </span> <a href="#" data-nofollow="true"><b><%- artist %></b> - <%- name %></a> <i class="x" title='eliminar'></i> </li>
#   </script>
#   <script id="modal_item_suggest" type="text/template">
#    <li data-lid="<%- item.imu %>" data-dns="<%- item.dns %>" data-url="<%- item.url %>" data-name="<%- item.txt %><%- item.extra_txt %>" data-art="<%- item.art %>"> <a href="#"> <%- item.txt %><%- item.extra_txt %> - <%- item.art %></a> </li>
#   </script>
#   <script>
#    if (!("IntersectionObserver" in window)) {
# 		var s = document.createElement("script");
# 		s.async = false;
# 		s.src = '//akamai.sscdn.co/letras/static/js/polyfills-es.vdb7f638b.js';
# 		document.head.appendChild(s);
# 	}
#   </script>
#   <script async="" src="//akamai.sscdn.co/letras/common/static/js/headscripts.vf911de7d.js">
#   </script>
#   <script async="" src="//akamai.sscdn.co/letras/common/static/js/prebid.v134045b4.js">
#   </script>
#   <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <script async="" src="//akamai.sscdn.co/letras/static/js/index.m-es.v0b71fd0a.js" type="module">
#   </script>
#   <script async="" nomodule="" src="//akamai.sscdn.co/letras/static/js/index-es.v2448fef4.js">
#   </script>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-446764-1', 'auto', {'sampleRate': 10});
# ga('send', 'pageview');
# (function (w, d, s, l, i) {
#     w[l] = w[l] || []; w[l].push({
#         'gtm.start':
#             new Date().getTime(), event: 'gtm.js'
#     }); var f = d.getElementsByTagName(s)[0],
#         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#             'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
# })(window, document, 'script', 'dataLayer', 'GTM-KWMSHG8');
# window.dataLayer = window.dataLayer || [];
#   </script>
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KWMSHG8" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#  </body>
# </html>

# %% [markdown]
# ## Finding every song tag element in page

# %%
songs_items = soup.find_all('li', class_='cnt-list-row')
songs_items[0]
# Out:
# <li class="cnt-list-row -song is-visible" data-artist="Imagine Dragons" data-dns="imagine-dragons" data-id="2876080" data-name="Believer" data-sharetext="Believer de Imagine Dragons" data-shareurl="https://www.letras.com/imagine-dragons/believer/" data-url="believer"> <a class="song-name" href="/imagine-dragons/believer/"><span>Believer</span></a> <div class="song-options"></div> </li>

# %% [markdown]
# ## Getting all the songs urls from the artist page

# %%
def get_songs_list(artist_url: str) -> list[str]:
    """
    Returns a list with all the songs urls of a given artist

    Args:
        artist_url (str): Artist url rfom letras.com

    Returns:
        list[str]: A list containing the songs urls as strings
    """
    url = artist_url + 'mais_acessadas.html'    # Required for this web
    page = requests.get(url)

    # Parsing web content with BeautifulSoup
    soup = bs(page.content, 'html.parser')
    # Looking for al the 'li' items with 'cnt-list-row' class in the html
    songs_items = soup.find_all('li', class_='cnt-list-row')

    # For every "li" item, we extract the "data-shareurl" tag inside
    songs_urls = [song.get("data-shareurl") for song in songs_items]

    return songs_urls

# %%
get_songs_list("https://www.letras.com/luis-miguel/")[:3]
# Out:
# ['https://www.letras.com/luis-miguel/108649/',
#  'https://www.letras.com/luis-miguel/26107/',
#  'https://www.letras.com/luis-miguel/26102/']

# %% [markdown]
# ## Defining function to get the lyric from a song page

# %%
def get_lyrics_from_url(song_url: str) -> str:
    """
    Extract the lyrics of a song page

    Args:
        song_url (str): Url of a song

    Returns:
        str: The lyrics of the given song's url
    """    

    song = requests.get(song_url)
    song = bs(song.content, 'html.parser')
    lyric_div = song.find('div', class_='cnt-letra')
    parrafos = lyric_div.find_all('p')

    lyric = ""

    for parrafo in parrafos:
        text = str(parrafo)
        text = text.replace("<br>", "\n")
        text = text.replace("<br/>", "\n")
        text = text.replace("</br>", "")
        text = text.replace("<p>", "")
        text = text.replace("</p>", "\n")
        lyric += text + "\n"

    lyric = lyric[:-2] # Remove extra \n
    
    return lyric

# %%
print(get_lyrics_from_url("https://www.letras.com/travis-scott/maria-im-drunk/"))
# Out:
# [Travis Scott]
# Made it to LA, yeah
# Finally in LA, yeah
# Lookin' for the weed though
# Trying to make my own dough
# Callin' for Maria
# Lost without Maria
# Might dive in the marina, oh, yeah, oh
#
# So trust me, baby, trust me
# Trust me, baby, trust me
# Trust me, baby, trust me
# I don't mind
# Trust me, baby, trust me
# Trust me, baby, trust me
# Trust me, baby, trust me
# I don't mind
#
# Trust me, trust me
# Trust me, trust me
# Trust me, trust me
# Yeah, I don't mind
#
# [Young Thug &amp; Travis Scott]
# Travis Scott
# (You know)
# Thugger Thugger, nigga, ay
#
# Ay, call your friends, let's get drunk
# Call your friends, let's get drunk
# (Call your friends and let's get drunk)
# Call your friends, let's get drunk
# (Call your friends and let's get drunk, ay)
# Call your friends, let's get drunk
# Call your friends, let's get drunk
# Call your friends, let's get drunk
# (Call your friends and let's get drunk)
# Call your friends, let's get drunk
# (Call your friends and let's get drunk)
# Call your friends, let's get drunk
#
# Twelve more hours left for us in a day
# (Call your friends and let's get drunk)
# I've been drinkin' all day, I've been floatin' all day
# (Call your friends and let's get drunk, ay)
# Bring your ass over here now, you know where, how I stay
# I've been gone for some time now, I just want a lil' taste
# Mix it, mix it, pour (lean, lean)
# (Call your friends and let's get drunk)
# Drinkin', sippin', slow
# (Call your friends and let's get drunk, ay)
# Drink so cold now, froze
# Froze, froze
# Come on over, get drunk
#
# [Justin Bieber &amp; Young Thug]
# Damn, girl, I'll be up late
# If you want, you can meet me at the studio
# (Call your friends and let's get drunk, ay)
# Yeah, I've been drinkin' all night
# Take a shot, all we got is Don Julio
# (Call your friends and let's get drunk, ay)
# Yeah, I'm guessin' this is new to you
# Thinkin' 'bout all the things that I would do to you
# Them lips on fire and them hips don't lie
# Girl, I just wanna see what that booty do (that's right)
#
# Let's lose each other's mind
# Let's make each other's night
# We'll take advantage of time
# While we're both intertwined
# Girl, I want you on the rocks, no chaser
# Be sure to drink it all, won't waste ya
# I know you stay sober
# I'm sure a few drinks won't faze ya
#
# [Young Thug]
# Call your friends, let's get drunk (hol' up)
# Call your friends, let's get drunk
# (Call your friends and let's get drunk)
# Call your friends, let's get drunk
# (Call your friends and let's get drunk)
# Ay, call your friends, let's get drunk
# Call your friends, let's get drunk
# Call your friends, let's get drunk
# (Call your friends and let's get drunk)
# Call your friends, let's get drunk
# (Call your friends and let's get drunk)
# Call your friends, let's get drunk
#
# Caress lil' mama for weed, and she did it for free
# (Call your friends and let's get drunk)
# Yeah, that thing wet, baby, I need skis
# (Call your friends and let's get drunk, ay)
# Skrrrr, yeah, I need to skeet, yeah, oh
#
# Run it back from the track (ay)
# Then I'ma speed race in that (skrr)
# Lil' mama still got my back (ay)
# Pull down your pants, I want crack (yeah)
# I'm growing weed, this ain't trees (bitch)
# My bitch brown like Hennessy (bitch)
# Big blood like Freddy in dreams (bitch)
# Dressed in a tie like the Dean (bitch)
# Drunk and in love with my baby
# Baby do not go fast, go slow, wait
# Tell me, tell me information I got rank, tell me
# Let's take a shot together and then lay up like planks
# Never ever, do I wanna leave my little lady (ay)
# Patrón down, back down, they got a plan 'fore that boy wake (yah)
# Told God if I get a iced out watch I won't be late (I promise)
# Every time I try to stick it in all the way
# Baby girl be like ayy, ayy, ayy, ayy, ayy, ayy
#
# [Young Thug &amp; Travis Scott]
# Call your friends, let's get drunk (let's get drunk, ay)
# Call your friends, let's get drunk
# (Call your friends and let's get drunk)
# Call your friends, let's get drunk
# (Call your friends and let's get drunk)
# Call your friends, let's get drunk
# Call your friends, let's get drunk
# Call your friends, let's get drunk
# (Call your friends and let's get drunk)
# Call your friends, let's get drunk
# (Call your friends and let's get drunk)
# Call your friends, let's get drunk
#
# [Young Thug]
# Call your friends and let's get drunk
# Call your friends and let's get drunk, ay

# %% [markdown]
# ### Another way: getting the lyrics from a div tag
# This will allow us to avoid redundant requests when we want more information about a given song url

# %%
def get_lyrics_from_div(div) -> str:
    """
    Extract the lyrics of a div

    Args:
        div (bs.element.Tag): div tag containing the lyrics

    Returns:
        str: The lyrics of the given song
    """    
    parrafos = div.find_all('p')

    lyric = ""

    for parrafo in parrafos:
        text = str(parrafo)
        text = text.replace("<br>", "\n")
        text = text.replace("<br/>", "\n")
        text = text.replace("</br>", "")
        text = text.replace("<p>", "")
        text = text.replace("</p>", "\n")
        lyric += text + "\n"

    lyric = lyric[:-2] # Remove extra \n
    
    return lyric

# %%
def get_lyrics_from_div_nobreaklines(div) -> str:
    """
    Extract the lyrics of a div with no break lines in text

    Args:
        div (bs.element.Tag): div tag containing the lyrics

    Returns:
        str: The lyrics of the given song
    """    
    parrafos = div.find_all('p')

    lyric = ""

    # We use regex to extract and clean the lyrics
    for parrafo in parrafos:

        # Alternartive to get lyrics without breaklines
        # Separate camelCase words (e.g. camelCase -> camel Case)
        lyric += re.sub(r"\B([A-Z])", r" \1", parrafo.text)
        
        # Remove extra spaces
        lyric = re.sub(' +', ' ', lyric)

    lyric = lyric[:-2] # Remove extra \n
    
    return lyric

# %%
print(get_lyrics_from_url('https://www.letras.com/imagine-dragons/demons/'))
# Out:
# When the days are cold
# And the cards all fold
# And the saints we see
# Are all made of gold
#
# When your dreams all fail
# And the ones we hail
# Are the worst of all
# And the blood's run stale
#
# I wanna hide the truth
# I wanna shelter you
# But with the beast inside
# There's nowhere we can hide
#
# No matter what we breed
# We still are made of greed
# This is my kingdom come
# This is my kingdom come
#
# When you feel my heat
# Look into my eyes
# It's where my demons hide
# It's where my demons hide
# Don't get too close
# It's dark inside
# It's where my demons hide
# It's where my demons hide
#
# At the curtain's call
# Is the last of all
# When the lights fade out
# All the sinners crawl
# So they dug your grave
# And the masquerade
# Will come calling out
# At the mess you made
#
# Don't wanna let you down
# But I am hell bound
# Though this is all for you
# Don't wanna hide the truth
#
# No matter what we breed
# We still are made of greed
# This is my kingdom come
# This is my kingdom come
#
# When you feel my heat
# Look into my eyes
# It's where my demons hide
# It's where my demons hide
# Don't get too close
# It's dark inside
# It's where my demons hide
# It's where my demons hide
#
# They say it's what you make
# I say it's up to fate
# It's woven in my soul
# I need to let you go
# Your eyes, they shine so bright
# I wanna save that light
# I can't escape this now
# Unless you show me how
#
# When you feel my heat
# Look into my eyes
# It's where my demons hide
# It's where my demons hide
# Don't get too close
# It's dark inside
# It's where my demons hide
# It's where my demons hide

# %% [markdown]
# ## Joining previous functions to get all the info of a song

# %%
def get_song_info(song_url: str) -> dict:
    """
    Returns a dictionary containing important information of a song, such as
    its name, lyrics and url
    
    Args:
        song_url (str): url of song

    Returns:
        dict: Dictionary with the song info
    """

    song = requests.get(song_url)
    song = bs(song.content, 'html.parser')

    # Getting the song name
    song_name = song.find("div", class_="cnt-head_title").find("h1").text

    # Getting song lyrics
    lyric_div = song.find('div', class_='cnt-letra')
    lyrics = get_lyrics_from_div(lyric_div)
    
    # Returning result dict
    return {
        "name": song_name,
        "lyrics": lyrics,
        "url": song_url
    }

# %%
print(get_song_info("https://www.letras.com/imagine-dragons/believer/")["lyrics"])
# Out:
# First things first
# I'ma say all the words inside my head
# I'm fired up and tired of the way
# That things have been, oh-ooh
# The way that things have been, oh-ooh
# Second things second
# Don't you tell me what you think that I could be
# I'm the one at the sail, I'm the master of my sea, oh-ooh
# The master of my sea, oh-ooh
#
# I was broken from a young age
# Taking my sulking to the masses
# Writing my poems for the few
# That look at me, took to me, shook to me, feeling me
# Singing from heartache from the pain
# Taking my message from the veins
# Speaking my lesson from the brain
# Seeing the beauty through the
#
# Pain!
# You made me a, you made me a believer, believer
# Pain!
# You break me down and build me up, believer, believer
# Pain!
# Oh, let the bullets fly, oh, let them rain
# My life, my love, my drive, they came from
# Pain!
# You made me a, you made me a believer, believer
#
# Third things third
# Send a prayer to the ones up above
# All the hate that you've heard
# Has turned your spirit to a dove, oh-ooh
# Your spirit up above, oh-ooh
#
# I was choking in the crowd
# Building my rain up in the cloud
# Falling like ashes to the ground
# Hoping my feelings, they would drown
# But they never did, ever lived, ebbing and flowing
# Inhibited, limited
# Till it broke open and rained down
# And rained down, like
#
# Pain!
# You made me a, you made me a believer, believer
# Pain!
# You break me down and build me up, believer, believer
# Pain!
# Oh, let the bullets fly, oh, let them rain
# My life, my love, my drive, they  came from
# Pain!
# You made me a, you made me a believer, believer
#
# Last things last
# By the grace of the fire and the flames
# You're the face of the future
# The blood in my veins, oh-ooh
# The blood in my veins, oh-ooh
# But they never did, ever lived, ebbing and flowing
# Inhibited, limited
# Till it broke open and rained down
# And rained down, like
#
# Pain!
# You made me a, you made me a believer, believer
# Pain!
# You break me down and build me up, believer, believer
# Pain!
# Oh, let the bullets fly, oh, let them rain
# My life, my love, my drive, they  came from
# Pain!
# You made me a, you made me a believer, believer

# %% [markdown]
# ## Get artist songs

# %%
def get_artist_songs(artist_url: str) -> list[dict]:
    """
    Returns name, lyrics and url of every song of an artist url in JSON format
    
    Args:
        artist_url (str): letras.com main page artist url

    Returns:
        list[dict]: List of dictionary with the info (JSON format)
    """
    urls = get_songs_list(artist_url)

    data = [get_song_info(url) for url in urls]
    return data

# %% [markdown]
# ## Scrapping artist songs concurrently

# %%
def scrap_songs_concurrently(artist_url: str, output_name: str) -> int:
    """
    Creates a json file with the songs info of an artist.
    Returns the number of songs scrapped.

    Args:
        artist_url (str): letras.com main page artist url
        output_name (str): name of created json file

    Returns:
        int: Number of songs scrapped.
    """
    
    songs_urls = get_songs_list(artist_url)
    songs_info = [get_song_info(url) for url in songs_urls]

    with open(f"{output_name}.json", "w") as fp:
        json.dump(songs_info, fp, indent=4)

    return len(songs_info)

# %%
start_time = time.time()
num_songs = scrap_songs_concurrently("https://www.letras.com/imagine-dragons/", "imagine_dragons_test2_concurrently")
end_time = time.time()
print(f"It took {round(end_time-start_time, 2)} seconds to get {num_songs} songs using Concurrently.")
# Out:
# It took 58.14 seconds to get 167 songs using Concurrently.

# %% [markdown]
# ## Scrapping artist songs with Threading

# %%
import concurrent.futures

def scrap_songs_threading(artist_url: str, output_name: str) -> int:
    """
    Creates a json file with the songs info of an artist using multithreading.
    Returns the number of songs scrapped.

    Args:
        artist_url (str): letras.com main page artist url
        output_name (str): name of created json file

    Returns:
        int: Number of songs scrapped.
    """

    songs_urls = get_songs_list(artist_url)
    # songs_info = []

    # def insert_song_info(url):
    #     songs_info.append(get_song_info(url))

    with concurrent.futures.ThreadPoolExecutor() as executor:
        results = executor.map(get_song_info, songs_urls)

        songs_info = [result for result in results]

    with open(f"{output_name}.json", "w") as fp:
        json.dump(songs_info, fp, indent=4)

    return len(songs_info)

# %%
start_time = time.time()
num_songs = scrap_songs_threading("https://www.letras.com/imagine-dragons/", "imagine_dragons_test2_threading")
end_time = time.time()
print(f"It took {round(end_time-start_time, 2)} seconds to get {num_songs} songs using Multithreading.")
# Out:
# It took 15.46 seconds to get 167 songs using Multithreading.

# %% [markdown]
# ## Scrapping artist songs with Multiprocessing

# %%
import time

# %%
#? It is necessary to do it this way to avoid BrokenProcessPool exception
import scrap
import concurrent.futures

if __name__ == "__main__":
    start_time = time.time()
    songs_urls = scrap.get_songs_list("https://www.letras.com/imagine-dragons/")

    with concurrent.futures.ProcessPoolExecutor() as executor:
        results = executor.map(scrap.get_song_info, songs_urls)

        songs_info = [result for result in results]

    with open("imagine_dragons_test2_multiprocessing.json", "w") as fp:
            json.dump(songs_info, fp, indent=4)

    end_time = time.time()
    print(f"It took {round(end_time-start_time, 2)} seconds to get {len(songs_info)} songs using Multiprocessing.")
# Out:
# It took 17.66 seconds to get 167 songs using Multiprocessing.
